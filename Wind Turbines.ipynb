# %% [markdown]
# ## Wind Turbines
#
# #### Historical Development of wind energy utilization
#
# Like many developments in technology, modern wind energy utilization by means of wind turbines started 40 years ago due to search for alternative energy sources except oil, whose deficiency and high prices were a global crisis issue. At first times of development, countries excluding Denmark tried to produce these wind turbines by experiences used in aerospace technology which has very high power ratings of MWs. After the understanding of the fact that produced turbines were bulky and inefficient in terms of reasonable cost of energy and  required different technology than aeroplanes motors, all governments started follow Denmarks' path. Denmark started the wind turbine technology by developing small wind turbines first and encouraged the individiuals and small companies.Today, more than 40 per cent of Denmark’s energy supply comes from wind power and the plan is to reach 50 per cent by 2020, as set out in the 2012 Energy Act.Total wind energy capacity in Denmark was 4,890 MW by the end of 2014, 3,620 MW onshore and 1,271 MW offshore[[21]](http://denmark.dk/en/green-living/wind-energy/). Denmark has some of most important wind energy manufacturers worldwide such as [Vestas](https://www.vestas.com/) and [Bonus Energy A/S-lately was acquired by Siemens](http://www.energy.siemens.com/hq/en/renewable-energy/wind-power/)
#
# Wind turbine is an important issue for renewable energy. Especially for the last decade its technology is substantially matured.
#
# According to [[1]](http://ieeexplore.ieee.org/xpl/articleDetails.jsp?arnumber=6216474) the global installed utility scale wind power was 197 GW at the end of 2010 (an increase of 24.1%) while the globalmarket for small wind turbines (SWTs) grew by only 4%.
#
# Wind turbine generators dominating the markets nowadays have 300-800 kW power output capacity in average.But the challenges and trends are toward to 1 MW per turbine thanks to promising concepts such as direct-drive[16].
#
#
# **The cost per swept area** is used rather than just the **cost of the turbines** or **cost per rated power** since the swept area gives a better indication of the total energy that can be generated by the turbine than the rated power given by the
# manufacturer. Besides that, when designing and investing a wind power stations,3 main properties which are necessary to validate are given as follows:
#
# * Low cost
#
# * long-lasting
#
# * Low service requirement
#
# These are called $L^{3}$ conditions[21]
#
# Small wind turbines(there is no certain definition about the scale but we can assume that for kw scale ones) can be categorized in two types:
# * Horizontal axis wind turbines (HAWT)
# * Vertical axis wind turbines (VAWT)

# %%
from IPython.display import Image
Image(filename='horizontal.png')

# %% [markdown]
# Horizontal axis wind turbine

# %%
from IPython.display import Image
Image(filename='vertical.jpg')

# %% [markdown]
# Vertical axis wind turbine

# %% [markdown]
# * In general, the efficiency of small wind turbines is low compared with large
# wind turbines.
#
# * Another important issue is speed control of these turbines. At this point two main control techniques are exist: **furling control** and **pitch control** .
#
# * There are no standards about what wind speed manufacturers should give the output power of their turbine (rated power). Therefore, there are some differences between the manufacturer's plate values and actual measured values.

# %% [markdown]
# ### Power Equations for Wind Energy
#
# The available shaft power(output power) $P$ from a wind turbine can be expressed as a function of the wind speed as follows :
#
# ## $$P = \frac{1}{2}\rho_{air}C_{p}(\lambda,\beta)\pi r^2v^3$$
# where,
#
# $\rho_{air}$ is the mass density of air
#
# $C_{p}(\lambda,\beta)$ is the power coefficient, a function of the tip speed ratio $\lambda$ and the pitch angle $\beta$
#
#
# $r$ is the blade length
#
# $v$ is the wind velocity

# %% [markdown]
# #### Power Coefficient
#
# Power coefficient(sometimes called performance coefficient) is basically can be defined as the ratio between captured wind power by the wind turbine and the available input power of the wind.Therefore it tells us **how efficiently** we utilize the wind turbine.Its value is sometimes taken from look up tables or can be assumed by nonlinear computations.[25]
#
# In [19](http://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=6226866&isnumber=6331663) Power coefficient $C_{p}$ is defined  as a nonlinear function of TSR($\lambda$) and pitch angle $\beta$ as follows,
#
# ### $$C_{p}=c_{1}(\frac{c_{2}}{\lambda_{i}}-c_{3}\beta-c_{4})e^{\frac{-c_{5}}{\lambda_{i}}}+c_{6}\lambda$$
#
# where
#
# ### $$\frac{1}{\lambda_{i}}=\frac{1}{\lambda+0.08\beta}-\frac{0.035}{\beta^3+1}$$
#
# The coefficients(depends on the turbine characteristics):
#
# $c_{1}$=0.5176
#
# $c_{2}$=116
#
# $c_{3}$=0,4
#
# $c_{4}$=5
#
# $c_{5}$=21
#
# $c_{6}$=0,0068
#
# Authors calculated the $C_{p}$ values for fixed pitch angle at a specific wind speed. Relation between TSR and $C_{p}$ is shown below,

# %%
from IPython.display import Image
Image(filename='tsr1.png')

# %% [markdown]
# #### Tip Speed Ratio
#
# * Tip speed ratio $\lambda$ (TSR) is defined as a ratio of tip speed of turbine blade to speed of the wind. This ratio is very useful when designing a wind turbine.
#
# $$\lambda = \frac{R\omega_{M}}{V} $$
#
# where,
# $V$ is the wind speed
#
# $\omega_{M}$ is the rotational rotor speed
#
# $R$ is the rotor radius
#
#
#
# * TSR is a kind of measurement of how speedy turbine blades turn. This topic is very important because of the efficiency issues. If turbine blades turns too slow then incoming air to the turbine is not used efficiently (Remember Betz limit!). If turbine blades turns too fast, blades act like solid wall to the turbine and then efficiency decreases again.To avoid bad consequences(low efficiency, physical breakdown) of turbulence issue,choosing optimal TSR is really important.
# * Approximate optimal TSR’s for a system:

# %%
from IPython.display import Image
Image(filename='tsr.png')

# %% [markdown]
# #### Betz Limit
# * Theoretically maximum **59%** (theoretical maximal of $C_{p}$ ) of energy carried by the wind can be extracted by a wind turbine. This result is concluded by German physicist **Albert Betz**
# * Generally imperfections and in blade manufacture reduces the actual energy yield of the turbine less than the useable energy.
#
# #### Weibull Distribution and other issues
# * Time dependent nature of the wind determines the production scheme of the WECs(Wind Energy Conversion Systems). There are some approaches for estimate the wind profile at given place. Wind profile at any given area is generally measured 10 meters above the ground level and estimated by **1/7 Power Profile Law** as given follows[25] :
#
# ### $$\frac{v}{v_{0}}=(\frac{h}{h_{0}})^{\alpha(v_{0},h_{0})}$$
#
# where,
#
# $v$ is desired wind speed,
#
# $v_{0}$ is reference wind speed,
#
# $h$ is the desired height,
#
# $h_{0}$ is the reference height
#
#
# $\alpha$ value in the equation above can be calculated as follows[25],
#
# ### $$\alpha(v_{0},h_{0})=\frac{0.37-0.088\ln(v_{0})}{1-0.088\ln(\frac{h}{h_{0}})}$$
#
# this value is approximated as **"1/7"** in calculations.
#
#
#
#
#
#
#
#
#
# * One remote sensing tecnique of the wind profile is **LIDAR(Light Detection and Ranging)** which is based on Doppler Effect to determine wind characteristics. In another method, **ANFIS(Adaptive Neuro-fuzzy interference system)** based clustering algorithm is used to predict wind speed.
#
#
# * **Weibull distribution** is used to determine the wind distribution and gives an indication of what percentage of time a certain wind speed occurs in a given site. Weibull distribution is given as follows:
#
# ## $$f(v)=\frac{k}{a} (\frac{v}{a})^{(k-1)}e^{-(\frac{v}{a})^k}$$
# where,
#
# $v$ is the wind speed
#
# $k$ is the shape parameter
#
# $a$ is the scale parameter
#
# * Therefore energy yield over a period of time $T$ can be defined as follows,
#
# $$T\int P(v)f(v)dv$$
#
# where,
#  P is the generated power
#
#  f(v) is the Weibull function
#
#  T=8760 hours (1 year)

# %% [markdown]
# * Minimum wind speed that is needed to start to rotate the turbines' blade is **cut-in wind speed**

# %% [markdown]
# #### Wind Turbine Generator Classification
#
# - In WEC systems, we can categorize most common generators as follows,
#
# A) Based on electrical construction<br>
# <pre>a)Induction Generators
# <pre>-SCIG<br>
# -WRIG<br>
# -DFIG<br>
# </pre>b)Synchronous Generators<pre>
# -WRSG<br>
# -PMSG
# </pre></pre>B) Based on mechanical construction<br>
# <pre>a)Geared Drive<br>
# b)Direct drive

# %% [markdown]
# ##### A) Based on electrical construction
#
# ###### -Wound Rotor Induction Generator(WRIG)
#
# * These type of generators are used for variable speed applications, thus there will be dynamic slip control[25].This control is applied by connecting electronically controlled resistor blocks to rotor of the generator. Slip denotes the relation between the rotor speed and synchronous speed and is given by the formula as follows,
#
# #### $$s=\frac{N_{s}-N_{r}}{N_{s}}$$ <br>
# where,<br><br>$s$ is the slip<br><br>$N_{s}$ is synchronous speed<br><br>$N_{r}$ is rotor speed
#
#
#
# * Also there exists shunt capacitors connected to line for compensation purposes.Typical WRIG schematic diagram with these capacitors is shown below.

# %%
from IPython.display import Image
Image(filename='WRIG.png')

# %% [markdown]
# *WRIG schematic diagram*[25]<br>
# ###### -Squirrel Cage Induction Generator (SCIG)
#
# * This type of machine can be used with both fixed(Danish concept) and variable speed. Robustness, stable operation, lower maintanence makes SCIG preferable in WECs. But in order to get more efficient operation SCIG should be construted with low number of poles because high number of poles contruction becomes a drawback for SCIG. Thefore gear-boxes are generally used with SCIGs.<br><br>
# * Capacitor banks and Static Synchronous Compensators(STATCOM) are commonly used for reactive power compensation with SCIGs. Additionally, STATCOMs used for active and reactive power flow control for variable speed applications of SCIGs.<br><br>
# * In variable speed applications of SCIG back-to-back voltage source converters(VSCs) are employed in order to meet grid codes[25]. Schematic diagram of a this type WEC is given below.

# %%
from IPython.display import Image
Image(filename='SCIG_variable.png')

# %% [markdown]
# *SCIG with back-to-back VSC converter[25]*

# %% [markdown]
# * Danish concept is known for fixed speed operation and can be applied to SCIG too.Generator speed is determined according to grid electrical frequency.Circuit schematic and a Danish-concept turbine is given below.

# %%
from IPython.display import Image
Image(filename='danish2.png')

# %% [markdown]
# *SCIG with Danish concept[27]*

# %%
from IPython.display import Image
Image(filename='danish.png')

# %% [markdown]
# *Danish concept with 3 stage gear-box*

# %% [markdown]
# ###### -Doubly fed Induction Generators(DFIG)
#
# * Among these generator types, doubly-fed induction generator system with 3 stage gearbox (DFIG-3G) is the most common configuration at present[15].<br><br>
# * Although it consists more complicaated power electronic control it can control active and reactive power flow from to control within supply side or rotor side.<br><br>
# * Stator is connected to grid via transformer while rotor connected to grid via power electronic converter blocks.<br><br>
# * Sometimes second PGSC(parallel grid side converter) is used parallel with dc-link in order to control unbalanced conditions better. This kind of configuration of DFIG is shown in figure below

# %%
from IPython.display import Image
Image(filename='DFIG-1.png')

# %% [markdown]
# *DFIG configuration with double GSC* [25]

# %%
from IPython.display import Image
Image(filename='DFIG-2.png')

# %% [markdown]
# *Conventional grid connected DFIG* [25]

# %% [markdown]
# #### Drivetrain approaches
#
# ##### Geared drive
#
# Gear ratio is a measure of relationship between output and input speeds of dynamic system.
#
#
# $$Gear \ Ratio = \frac{Output \ speed}{Input\ speed} = \frac{Driven}{Driving}$$
#
# * Drivetrain of a VSCF turbine generally consists of blades,low and high speed shafts,gear-box and generator.
#
# * Gearbox in a wind turbine system is responsible of transmission of aerodynamic power from turbine to the generator shaft.

# %%
from IPython.display import Image
Image(filename='Drawing2.jpg')

# %% [markdown]
# ##### Direct drive

# %%
from IPython.display import Image
Image(filename='Drawing1.jpg')

# %% [markdown]
# ##### Drivetrain modelling
#
# * Drivetrain can be modelled single-mass or two mass model according to application[25]. If the system response to transients and other stability issues are the main focus of the analyze, two mass model is employed[25]. Two mass model of the drivetrain system is given as follows,

# %%
from IPython.display import Image
Image(filename='2mass.png')

# %% [markdown]
# *Drivetrain two-mass model*
#
# **Note:** mass with the *m* indice denotes turbine moment of inertia and other mass with "g" indice denotes generator moment of inertia.
#
# * Equations for angular speeds at the both end of the two-mass model are as follows[26],
#
# $$\frac{d\omega_{m}}{dt}=\frac{1}{J_{m}}(T_{m}-T_{dt}-T_{at}-T_{ts})$$ <br><br>
# $$\frac{d\omega_{g}}{dt}=\frac{1}{J_{g}}(T_{ts}-T_{dg}-T_{ag}-T_{g})$$<br>
# where,<br><br>
# $J_{m}$ is moment of inertia of blades and hub<br><br>
# $T_{m}$ is mechanical torque,<br><br>
# $T_{dt}$ is resistant torque in the wind turbine bearing<br><br>
# $T_{at}$ is resistant torque in the hub and blades <br><br>
# $J_{g}$ is moment of inertia of rotor of the generator<br><br>
# $T_{g}$ is electrical torque,<br><br>
# $T_{dg}$ is resistant torque in generator bearing<br><br>
# $T_{ag}$ is resistant torque for airflow in generator <br><br>
# $T_{ts}$ is torsional stifness torque<br><br>

# %% [markdown]
# * In some European countries, there is limited space for installing wind turbines onshore, so there is a increasing trend for install them offshore. However, installing these wind turbines offshore requires more expensive and frequent maintenance than that of onshore. Therefore direct-drive technology gains importance by its robust and simple drive-train and easy-to-install structure in practice.
#
#
# * Direct-drive(DD) wind turbine concept eliminates multi-stage gearbox which means extra cost of maintenance and extra mechanical cost in variable speed constant frequency(VSCF) type wind turbines
#
#
# * According to [Laithwaite](https://en.wikipedia.org/wiki/Eric_Laithwaite)'s and [Freris](http://www.lboro.ac.uk/departments/eese/staff/leon-freris/)'s work, power output of any rotating electrical machine can be generally desribed by the formula given below: (which is rough formula than given previous one)
#
# $$P=KD^2Ln$$
#
# where,
#
# D is rotor diameter
#
# L is length(axial)
#
# n is rotational speed
#
# K is constant
#
# * Note that output power is related to airgap diameter squared,therefore DD generators have larger diameters.
#
# * Since DD's have no gear-box, n is very small. Therefore,it's inevitable to increase diameter or axial length.Usually increasing diameter is more preferable since it affects the output power by square of resulting value.

# %% [markdown]
# #### Flux orientations
#
# One of the important options in design of the machine is magnetic flux path directions. Current technology in this topic can be classied as three main subgroups as follows:
#
# * Radial flux (path of the magnetic flux is perpendicular to the direction of the rotor shaft)
#
# * Axial flux (path of the magnetic flux is perpendicular to the radial direction of the rotor shaft)
#
# * Transverse flux (path of the magnetic flux is perpendicular to the direction of the rotor rotation)
#
# #### Grid connection and power electronic issues
#
# * Since C-GEN concept generators has no excitation windings(instead there are permanent magnets), output voltage is dependent on machine speed. Therefore, proper power electronics control circuits are needed to make efficient grid connection.
#
# * WECs based on power electronic converters(PEC) utilizes two different converter circuits and their control blocks. Their names are as follows
#
#     $a)$ RSC(rotor side converter) ~generally used in DFIG
#
#     $b)$ GSC(grid side converter)
#
#
# * There are three main schemes to be used in these circuit topologies:
#
# a) IGBT Supply side inverter
#
# * In this topology, generator output AC voltage is rectified with six diode bridge(uncontrolled) rectifier. Rectified uncontrolled voltage directly connected to DC-link capacitor.
#
# * Then this rectified voltages is converted again to AC voltage via inverter.
#
# * This topology has lower cost than other options since there is no controlled rectifier unit.
#
# Block diagram of this topology is given below:

# %%
from IPython.display import Image
Image(filename='igbtsupply.png')

# %% [markdown]
# *IGBT Supply side inverter option*

# %% [markdown]
# b) Intermediate DC/DC Converter
#
# * Biggest advantage of this topology is its cost-benefit especially when working with multiple turbine systems.
#
# * Instead of using uncontrolled and bulk dc-link capacitor, a DC chopper is used after rectifier unit.
#
# * By this chopper controlled inverter has more smooth and flexible control on grid connection. Also dc-link capacitors are smaller in size.
#
# * Maximum power point tracker algorithm can be used to drive chopper control(duty cycle) according to variable output power of the generator.
#
# Block diagram of this topology is given below:

# %%
from IPython.display import Image
Image(filename='intermediate.png')

# %% [markdown]
# *Intermediate dc/dc converter option*

# %% [markdown]
# c) Back-to-back PWM converter
#
# * Intead of using separate chopper and rectifier units, only one AC/DC circuit block can be used.
#
# * This option can require more complex control issues than other options.
#
# Block diagram of this topology is given below:

# %%
from IPython.display import Image
Image(filename='backtoback.png')

# %% [markdown]
# *Back-to-back converter option*

# %% [markdown]
# * When combining stacked generators into grid its important to choose number of generators in a group. Although number of a generator in a group is changed depend o the whole system, it's useful to group them in small number of parallel groups in order to maintain electricity generation during a fault condition.
#
#
# * Remember connection type can effect the equipment and overall efficiency:
#   - As number of series connected machine increases, dc-link voltage increases
#   - As number of parallel connected machine increases, dc-link current increases

# %% [markdown]
# #### Future challenges and ideas worth considering
#
# In this part, i try to list some aspects of wind turbines and Ddrive concept needs to be altered. Some of them are can be listed as follows:
#
# * As a long range aim, can these wind farms suppy active and reactive power in order to connect normally on grid in terms of promising power system stability alternative?
#
# * Is it possible to produce more efficient air-core structure(as mentioned in the C-Gen parts), in order to eliminate attraction force between stator and rotor parts especially in larger diameters of Ddrive concept?
#
# * Although it's some sort of mechanical aspect of design,how can we reduce structural mass which is larger than electromagnetically active part in Ddrive generators?
#
# * YASA (Yokeless and Segmented Armature) machines - Oxford YASA Motors company / eliminates long end windings and yoke structure
#
# * Any design which does not provide at least one element of $L^{3}$ conditions will be inefficient.
#
# * Finding critical gear-box ratio at which conventional geared motors are more efficient than gearless motors.
#
# **Note**: As i read papers and articles these issues will be updated
